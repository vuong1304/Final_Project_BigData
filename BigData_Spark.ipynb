# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg, max, min, year, month, stddev, variance, corr
from pyspark.sql.window import Window
from pyspark.sql import functions as F

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Khởi tạo SparkSession
spark = SparkSession.builder.appName("ClimateAnalysis").getOrCreate()

# Đọc dữ liệu từ file input.txt
df = spark.read.csv("/content/drive/MyDrive/dataset/VNweather_data.txt", header=True, inferSchema=True)

# %%
# Chuyển đổi kiểu dữ liệu của các cột sang số
numeric_cols = ["max", "min", "wind", "rain", "humidi", "cloud", "pressure"]
for col_name in numeric_cols:
    df = df.withColumn(col_name, col(col_name).cast("double"))

# %%
# Thêm cột temp (nhiệt độ trung bình), maxtemp, mintemp
df = df.withColumn("temp", (col("max") + col("min")) / 2)
df = df.withColumnRenamed("max", "maxtemp")
df = df.withColumnRenamed("min", "mintemp")
df = df.withColumnRenamed("humidi", "humidity")

# %%
# 1. Tính trung bình cực trị của các yếu tố khí hậu theo từng tỉnh
analysis_cols = ["maxtemp", "mintemp", "wind", "rain", "humidity", "cloud", "pressure", "temp"]

for col_name in analysis_cols:
    # Calculate max and min first
    extreme_df = df.groupBy("province").agg(
        max(col_name).alias(f"max_{col_name}"),
        min(col_name).alias(f"min_{col_name}")
    )
    # Then calculate the average of max and min in a separate step
    extreme_avg_by_province = extreme_df.groupBy("province").agg(
        avg(col(f"max_{col_name}")).alias(f"avg_max_{col_name}"),
        avg(col(f"min_{col_name}")).alias(f"avg_min_{col_name}")
    )
    print(f"Trung bình cực trị của {col_name} theo tỉnh:")
    extreme_avg_by_province.show()
# Out:
# Trung bình cực trị của maxtemp theo tỉnh:
# +----------------+---------------+---------------+
# |        province|avg_max_maxtemp|avg_min_maxtemp|
# +----------------+---------------+---------------+
# |      Long Xuyen|           40.0|           23.0|
# |          My Tho|           41.0|           21.0|
# |Ho Chi Minh City|           41.0|           22.0|
# |         Ben Tre|           41.0|           21.0|
# |       Nha Trang|           36.0|           19.0|
# |        Hong Gai|           35.0|            8.0|
# |       Hai Phong|           39.0|            7.0|
# |         Cam Pha|           34.0|            8.0|
# |       Hai Duong|           40.0|            8.0|
# |          Ca Mau|           39.0|           22.0|
# |        Cam Ranh|           35.0|           22.0|
# |         Play Cu|           40.0|           16.0|
# |        Nam Dinh|           43.0|            6.0|
# |        Chau Doc|           40.0|           22.0|
# |         Can Tho|           40.0|           22.0|
# |          Da Lat|           36.0|           14.0|
# |        Qui Nhon|           36.0|           19.0|
# |      Phan Thiet|           37.0|           23.0|
# |          Tan An|           41.0|           22.0|
# |             Hue|           39.0|           15.0|
# +----------------+---------------+---------------+
# only showing top 20 rows
#
# Trung bình cực trị của mintemp theo tỉnh:
# +----------------+---------------+---------------+
# |        province|avg_max_mintemp|avg_min_mintemp|
# +----------------+---------------+---------------+
# |      Long Xuyen|           30.0|           15.0|
# |          My Tho|           30.0|           17.0|
# |Ho Chi Minh City|           30.0|           16.0|
# |         Ben Tre|           30.0|           17.0|
# |       Nha Trang|           28.0|           13.0|
# |        Hong Gai|           31.0|            4.0|
# |       Hai Phong|           30.0|            5.0|
# |         Cam Pha|           30.0|            4.0|
# |       Hai Duong|           30.0|            6.0|
# |          Ca Mau|           30.0|           17.0|
# |        Cam Ranh|           28.0|           14.0|
# |         Play Cu|           24.0|            8.0|
# |        Nam Dinh|           32.0|            4.0|
# |        Chau Doc|           31.0|           16.0|
# |         Can Tho|           29.0|           16.0|
# |          Da Lat|           21.0|            8.0|
# |        Qui Nhon|           29.0|           12.0|
# |      Phan Thiet|           28.0|           16.0|
# |          Tan An|           30.0|           18.0|
# |             Hue|           29.0|           10.0|
# +----------------+---------------+---------------+
# only showing top 20 rows
#
# Trung bình cực trị của wind theo tỉnh:
# +----------------+------------+------------+
# |        province|avg_max_wind|avg_min_wind|
# +----------------+------------+------------+
# |      Long Xuyen|        28.0|         3.0|
# |          My Tho|        28.0|         3.0|
# |Ho Chi Minh City|        26.0|         2.0|
# |         Ben Tre|        28.0|         3.0|
# |       Nha Trang|        37.0|         3.0|
# |        Hong Gai|        52.0|         4.0|
# |       Hai Phong|        35.0|         2.0|
# |         Cam Pha|        47.0|         2.0|
# |       Hai Duong|        35.0|         2.0|
# |          Ca Mau|        34.0|         2.0|
# |        Cam Ranh|        50.0|         4.0|
# |         Play Cu|        33.0|         2.0|
# |        Nam Dinh|        31.0|         3.0|
# |        Chau Doc|        28.0|         3.0|
# |         Can Tho|        31.0|         3.0|
# |          Da Lat|        19.0|         1.0|
# |        Qui Nhon|        43.0|         4.0|
# |      Phan Thiet|        31.0|         3.0|
# |          Tan An|        26.0|         3.0|
# |             Hue|        48.0|         2.0|
# +----------------+------------+------------+
# only showing top 20 rows
#
# Trung bình cực trị của rain theo tỉnh:
# +----------------+------------+------------+
# |        province|avg_max_rain|avg_min_rain|
# +----------------+------------+------------+
# |      Long Xuyen|       107.2|         0.0|
# |          My Tho|        91.4|         0.0|
# |Ho Chi Minh City|       253.3|         0.0|
# |         Ben Tre|        91.4|         0.0|
# |       Nha Trang|       401.3|         0.0|
# |        Hong Gai|       240.9|         0.0|
# |       Hai Phong|       177.4|         0.0|
# |         Cam Pha|       252.2|         0.0|
# |       Hai Duong|       186.7|         0.0|
# |          Ca Mau|       126.6|         0.0|
# |        Cam Ranh|       596.4|         0.0|
# |         Play Cu|       223.4|         0.0|
# |        Nam Dinh|       124.7|         0.0|
# |        Chau Doc|       135.0|         0.0|
# |         Can Tho|        42.2|         0.0|
# |          Da Lat|       314.1|         0.0|
# |        Qui Nhon|       289.0|         0.0|
# |      Phan Thiet|       118.8|         0.0|
# |          Tan An|       201.3|         0.0|
# |             Hue|       438.1|         0.0|
# +----------------+------------+------------+
# only showing top 20 rows
#
# Trung bình cực trị của humidity theo tỉnh:
# +----------------+----------------+----------------+
# |        province|avg_max_humidity|avg_min_humidity|
# +----------------+----------------+----------------+
# |      Long Xuyen|            96.0|            46.0|
# |          My Tho|            97.0|            49.0|
# |Ho Chi Minh City|            97.0|            45.0|
# |         Ben Tre|            97.0|            49.0|
# |       Nha Trang|            95.0|            60.0|
# |        Hong Gai|            97.0|            31.0|
# |       Hai Phong|            97.0|            29.0|
# |         Cam Pha|            97.0|            32.0|
# |       Hai Duong|            97.0|            30.0|
# |          Ca Mau|            94.0|            53.0|
# |        Cam Ranh|            95.0|            61.0|
# |         Play Cu|           100.0|            36.0|
# |        Nam Dinh|            98.0|            35.0|
# |        Chau Doc|            96.0|            45.0|
# |         Can Tho|            97.0|            47.0|
# |          Da Lat|           100.0|            37.0|
# |        Qui Nhon|            95.0|            58.0|
# |      Phan Thiet|            94.0|            53.0|
# |          Tan An|            97.0|            47.0|
# |             Hue|            97.0|            56.0|
# +----------------+----------------+----------------+
# only showing top 20 rows
#
# Trung bình cực trị của cloud theo tỉnh:
# +----------------+-------------+-------------+
# |        province|avg_max_cloud|avg_min_cloud|
# +----------------+-------------+-------------+
# |      Long Xuyen|         98.0|          0.0|
# |          My Tho|         96.0|          0.0|
# |Ho Chi Minh City|         99.0|          0.0|
# |         Ben Tre|         96.0|          0.0|
# |       Nha Trang|        100.0|          0.0|
# |        Hong Gai|        100.0|          0.0|
# |       Hai Phong|        100.0|          0.0|
# |         Cam Pha|        100.0|          0.0|
# |       Hai Duong|        100.0|          0.0|
# |          Ca Mau|         98.0|          1.0|
# |        Cam Ranh|        100.0|          0.0|
# |         Play Cu|        100.0|          1.0|
# |        Nam Dinh|        100.0|          0.0|
# |        Chau Doc|        100.0|          0.0|
# |         Can Tho|         97.0|          1.0|
# |          Da Lat|        100.0|          0.0|
# |        Qui Nhon|        100.0|          0.0|
# |      Phan Thiet|        100.0|          0.0|
# |          Tan An|         98.0|          0.0|
# |             Hue|        100.0|          0.0|
# +----------------+-------------+-------------+
# only showing top 20 rows
#
# Trung bình cực trị của pressure theo tỉnh:
# +----------------+----------------+----------------+
# |        province|avg_max_pressure|avg_min_pressure|
# +----------------+----------------+----------------+
# |      Long Xuyen|          1017.0|          1003.0|
# |          My Tho|          1017.0|          1002.0|
# |Ho Chi Minh City|          1017.0|          1002.0|
# |         Ben Tre|          1017.0|          1002.0|
# |       Nha Trang|          1020.0|           997.0|
# |        Hong Gai|          1036.0|           991.0|
# |       Hai Phong|          1037.0|           992.0|
# |         Cam Pha|          1036.0|           992.0|
# |       Hai Duong|          1037.0|           991.0|
# |          Ca Mau|          1016.0|          1004.0|
# |        Cam Ranh|          1019.0|           998.0|
# |         Play Cu|          1022.0|           994.0|
# |        Nam Dinh|          1036.0|           991.0|
# |        Chau Doc|          1017.0|          1002.0|
# |         Can Tho|          1017.0|          1003.0|
# |          Da Lat|          1019.0|           999.0|
# |        Qui Nhon|          1021.0|           994.0|
# |      Phan Thiet|          1017.0|          1001.0|
# |          Tan An|          1017.0|          1002.0|
# |             Hue|          1026.0|           992.0|
# +----------------+----------------+----------------+
# only showing top 20 rows
#
# Trung bình cực trị của temp theo tỉnh:
# +----------------+------------+------------+
# |        province|avg_max_temp|avg_min_temp|
# +----------------+------------+------------+
# |      Long Xuyen|        34.5|        21.0|
# |          My Tho|        35.0|        20.5|
# |Ho Chi Minh City|        34.5|        21.0|
# |         Ben Tre|        35.0|        20.5|
# |       Nha Trang|        31.5|        18.0|
# |        Hong Gai|        32.0|         6.5|
# |       Hai Phong|        34.0|         6.0|
# |         Cam Pha|        31.5|         6.5|
# |       Hai Duong|        35.0|         7.0|
# |          Ca Mau|        33.5|        20.0|
# |        Cam Ranh|        31.5|        18.0|
# |         Play Cu|        31.0|        15.0|
# |        Nam Dinh|        37.0|         5.5|
# |        Chau Doc|        34.5|        19.5|
# |         Can Tho|        34.0|        20.5|
# |          Da Lat|        27.5|        12.0|
# |        Qui Nhon|        32.5|        15.5|
# |      Phan Thiet|        32.0|        21.0|
# |          Tan An|        35.0|        21.5|
# |             Hue|        33.5|        13.5|
# +----------------+------------+------------+
# only showing top 20 rows

# %%
# 2. Tính trung bình cực trị của các yếu tố khí hậu của một tỉnh theo mùa
df = df.withColumn("month", month(col("date")))

def get_season(month):
    if month in [3, 4, 5]:
        return "Spring"
    elif month in [6, 7, 8]:
        return "Summer"
    elif month in [9, 10, 11]:
        return "Autumn"
    else:
        return "Winter"

get_season_udf = F.udf(get_season)
df = df.withColumn("season", get_season_udf(col("month")))

for col_name in analysis_cols:
    # Calculate max and min first
    extreme_df = df.groupBy("province", "season").agg(
        max(col_name).alias(f"max_{col_name}"),
        min(col_name).alias(f"min_{col_name}")
    )
    # Then calculate the average of max and min in a separate step
    extreme_avg_by_season = extreme_df.groupBy("province", "season").agg( # Group by both province and season
        avg(col(f"max_{col_name}")).alias(f"avg_max_{col_name}"),
        avg(col(f"min_{col_name}")).alias(f"avg_min_{col_name}")
    )
    print(f"Trung bình cực trị của {col_name} theo tỉnh và mùa:")
    extreme_avg_by_season.show()
# Out:
# Trung bình cực trị của maxtemp theo tỉnh và mùa:
# +-------------+------+---------------+---------------+
# |     province|season|avg_max_maxtemp|avg_min_maxtemp|
# +-------------+------+---------------+---------------+
# |          Hue|Summer|           38.0|           24.0|
# |       Tan An|Spring|           41.0|           24.0|
# |Buon Me Thuot|Autumn|           35.0|           20.0|
# |     Nam Dinh|Spring|           43.0|           10.0|
# |     Hong Gai|Spring|           34.0|           11.0|
# |     Rach Gia|Summer|           35.0|           25.0|
# |   Long Xuyen|Autumn|           36.0|           25.0|
# |      Play Cu|Summer|           34.0|           20.0|
# |          Hue|Winter|           34.0|           15.0|
# |     Bac Lieu|Spring|           39.0|           25.0|
# |      Cam Pha|Spring|           32.0|           11.0|
# |     Bac Lieu|Winter|           35.0|           22.0|
# |     Chau Doc|Summer|           37.0|           24.0|
# |        Hanoi|Winter|           42.0|            7.0|
# |     Bien Hoa|Winter|           39.0|           22.0|
# |       Ha Noi|Winter|           42.0|            7.0|
# |   Phan Thiet|Autumn|           36.0|           24.0|
# |       Ca Mau|Spring|           39.0|           25.0|
# |    Hai Phong|Summer|           39.0|           25.0|
# |      Cam Pha|Winter|           28.0|            8.0|
# +-------------+------+---------------+---------------+
# only showing top 20 rows
#
# Trung bình cực trị của mintemp theo tỉnh và mùa:
# +-------------+------+---------------+---------------+
# |     province|season|avg_max_mintemp|avg_min_mintemp|
# +-------------+------+---------------+---------------+
# |          Hue|Summer|           29.0|           18.0|
# |       Tan An|Spring|           30.0|           21.0|
# |Buon Me Thuot|Autumn|           24.0|           16.0|
# |     Nam Dinh|Spring|           32.0|            9.0|
# |     Hong Gai|Spring|           30.0|            8.0|
# |     Rach Gia|Summer|           30.0|           18.0|
# |   Long Xuyen|Autumn|           29.0|           21.0|
# |      Play Cu|Summer|           22.0|           17.0|
# |          Hue|Winter|           24.0|           10.0|
# |     Bac Lieu|Spring|           30.0|           21.0|
# |      Cam Pha|Spring|           29.0|            9.0|
# |     Bac Lieu|Winter|           27.0|           18.0|
# |     Chau Doc|Summer|           29.0|           18.0|
# |        Hanoi|Winter|           25.0|            2.0|
# |     Bien Hoa|Winter|           28.0|           18.0|
# |       Ha Noi|Winter|           25.0|            2.0|
# |   Phan Thiet|Autumn|           28.0|           21.0|
# |       Ca Mau|Spring|           30.0|           17.0|
# |    Hai Phong|Summer|           30.0|           22.0|
# |      Cam Pha|Winter|           23.0|            4.0|
# +-------------+------+---------------+---------------+
# only showing top 20 rows
#
# Trung bình cực trị của wind theo tỉnh và mùa:
# +-------------+------+------------+------------+
# |     province|season|avg_max_wind|avg_min_wind|
# +-------------+------+------------+------------+
# |          Hue|Summer|        20.0|         3.0|
# |       Tan An|Spring|        26.0|         3.0|
# |Buon Me Thuot|Autumn|        22.0|         2.0|
# |     Nam Dinh|Spring|        23.0|         3.0|
# |     Hong Gai|Spring|        29.0|         5.0|
# |     Rach Gia|Summer|        39.0|         3.0|
# |   Long Xuyen|Autumn|        27.0|         3.0|
# |      Play Cu|Summer|        23.0|         2.0|
# |          Hue|Winter|        21.0|         3.0|
# |     Bac Lieu|Spring|        34.0|         4.0|
# |      Cam Pha|Spring|        30.0|         2.0|
# |     Bac Lieu|Winter|        37.0|         4.0|
# |     Chau Doc|Summer|        28.0|         3.0|
# |        Hanoi|Winter|        25.0|         3.0|
# |     Bien Hoa|Winter|        18.0|         3.0|
# |       Ha Noi|Winter|        25.0|         3.0|
# |   Phan Thiet|Autumn|        29.0|         3.0|
# |       Ca Mau|Spring|        33.0|         3.0|
# |    Hai Phong|Summer|        31.0|         4.0|
# |      Cam Pha|Winter|        30.0|         4.0|
# +-------------+------+------------+------------+
# only showing top 20 rows
#
# Trung bình cực trị của rain theo tỉnh và mùa:
# +-------------+------+------------+------------+
# |     province|season|avg_max_rain|avg_min_rain|
# +-------------+------+------------+------------+
# |          Hue|Summer|       186.2|         0.0|
# |       Tan An|Spring|        66.8|         0.0|
# |Buon Me Thuot|Autumn|       157.3|         0.0|
# |     Nam Dinh|Spring|        22.7|         0.0|
# |     Hong Gai|Spring|        88.2|         0.0|
# |     Rach Gia|Summer|       122.2|         0.0|
# |   Long Xuyen|Autumn|       105.2|         0.0|
# |      Play Cu|Summer|       167.6|         0.0|
# |          Hue|Winter|       280.1|         0.0|
# |     Bac Lieu|Spring|        36.4|         0.0|
# |      Cam Pha|Spring|        83.1|         0.0|
# |     Bac Lieu|Winter|        31.1|         0.0|
# |     Chau Doc|Summer|       102.9|         0.0|
# |        Hanoi|Winter|        55.2|         0.0|
# |     Bien Hoa|Winter|        44.9|         0.0|
# |       Ha Noi|Winter|        55.2|         0.0|
# |   Phan Thiet|Autumn|        80.9|         0.0|
# |       Ca Mau|Spring|        48.6|         0.0|
# |    Hai Phong|Summer|       173.0|         0.0|
# |      Cam Pha|Winter|       112.5|         0.0|
# +-------------+------+------------+------------+
# only showing top 20 rows
#
# Trung bình cực trị của humidity theo tỉnh và mùa:
# +-------------+------+----------------+----------------+
# |     province|season|avg_max_humidity|avg_min_humidity|
# +-------------+------+----------------+----------------+
# |          Hue|Summer|            95.0|            58.0|
# |       Tan An|Spring|            94.0|            47.0|
# |Buon Me Thuot|Autumn|            99.0|            64.0|
# |     Nam Dinh|Spring|            97.0|            38.0|
# |     Hong Gai|Spring|            97.0|            48.0|
# |     Rach Gia|Summer|            95.0|            66.0|
# |   Long Xuyen|Autumn|            96.0|            57.0|
# |      Play Cu|Summer|           100.0|            70.0|
# |          Hue|Winter|            97.0|            60.0|
# |     Bac Lieu|Spring|            91.0|            54.0|
# |      Cam Pha|Spring|            97.0|            48.0|
# |     Bac Lieu|Winter|            92.0|            51.0|
# |     Chau Doc|Summer|            96.0|            61.0|
# |        Hanoi|Winter|            97.0|            28.0|
# |     Bien Hoa|Winter|            96.0|            45.0|
# |       Ha Noi|Winter|            97.0|            28.0|
# |   Phan Thiet|Autumn|            94.0|            63.0|
# |       Ca Mau|Spring|            92.0|            56.0|
# |    Hai Phong|Summer|            93.0|            57.0|
# |      Cam Pha|Winter|            96.0|            32.0|
# +-------------+------+----------------+----------------+
# only showing top 20 rows
#
# Trung bình cực trị của cloud theo tỉnh và mùa:
# +-------------+------+-------------+-------------+
# |     province|season|avg_max_cloud|avg_min_cloud|
# +-------------+------+-------------+-------------+
# |          Hue|Summer|         97.0|          1.0|
# |       Tan An|Spring|         95.0|          2.0|
# |Buon Me Thuot|Autumn|        100.0|          1.0|
# |     Nam Dinh|Spring|        100.0|          0.0|
# |     Hong Gai|Spring|        100.0|          1.0|
# |     Rach Gia|Summer|         97.0|          5.0|
# |   Long Xuyen|Autumn|         96.0|          6.0|
# |      Play Cu|Summer|        100.0|         18.0|
# |          Hue|Winter|        100.0|          0.0|
# |     Bac Lieu|Spring|         94.0|          2.0|
# |      Cam Pha|Spring|        100.0|          1.0|
# |     Bac Lieu|Winter|         93.0|          0.0|
# |     Chau Doc|Summer|        100.0|          5.0|
# |        Hanoi|Winter|        100.0|          0.0|
# |     Bien Hoa|Winter|         99.0|          0.0|
# |       Ha Noi|Winter|        100.0|          0.0|
# |   Phan Thiet|Autumn|         96.0|          2.0|
# |       Ca Mau|Spring|         87.0|          1.0|
# |    Hai Phong|Summer|         94.0|          0.0|
# |      Cam Pha|Winter|        100.0|          0.0|
# +-------------+------+-------------+-------------+
# only showing top 20 rows
#
# Trung bình cực trị của pressure theo tỉnh và mùa:
# +-------------+------+----------------+----------------+
# |     province|season|avg_max_pressure|avg_min_pressure|
# +-------------+------+----------------+----------------+
# |          Hue|Summer|          1012.0|           998.0|
# |       Tan An|Spring|          1015.0|          1005.0|
# |Buon Me Thuot|Autumn|          1015.0|           998.0|
# |     Nam Dinh|Spring|          1027.0|           999.0|
# |     Hong Gai|Spring|          1027.0|           999.0|
# |     Rach Gia|Summer|          1012.0|          1003.0|
# |   Long Xuyen|Autumn|          1013.0|          1003.0|
# |      Play Cu|Summer|          1013.0|          1002.0|
# |          Hue|Winter|          1026.0|          1007.0|
# |     Bac Lieu|Spring|          1015.0|          1005.0|
# |      Cam Pha|Spring|          1027.0|           999.0|
# |     Bac Lieu|Winter|          1016.0|          1006.0|
# |     Chau Doc|Summer|          1012.0|          1002.0|
# |        Hanoi|Winter|          1037.0|          1004.0|
# |     Bien Hoa|Winter|          1017.0|          1006.0|
# |       Ha Noi|Winter|          1037.0|          1004.0|
# |   Phan Thiet|Autumn|          1014.0|          1001.0|
# |       Ca Mau|Spring|          1015.0|          1005.0|
# |    Hai Phong|Summer|          1011.0|           992.0|
# |      Cam Pha|Winter|          1036.0|          1004.0|
# +-------------+------+----------------+----------------+
# only showing top 20 rows
#
# Trung bình cực trị của temp theo tỉnh và mùa:
# +-------------+------+------------+------------+
# |     province|season|avg_max_temp|avg_min_temp|
# +-------------+------+------------+------------+
# |          Hue|Summer|        33.0|        21.5|
# |       Tan An|Spring|        35.0|        23.0|
# |Buon Me Thuot|Autumn|        29.0|        19.0|
# |     Nam Dinh|Spring|        37.0|         9.5|
# |     Hong Gai|Spring|        31.0|        10.5|
# |     Rach Gia|Summer|        32.0|        22.0|
# |   Long Xuyen|Autumn|        32.0|        23.0|
# |      Play Cu|Summer|        28.0|        19.0|
# |          Hue|Winter|        28.5|        13.5|
# |     Bac Lieu|Spring|        34.5|        23.5|
# |      Cam Pha|Spring|        30.5|        10.5|
# |     Bac Lieu|Winter|        31.0|        20.5|
# |     Chau Doc|Summer|        32.5|        21.0|
# |        Hanoi|Winter|        32.0|         5.5|
# |     Bien Hoa|Winter|        32.0|        21.5|
# |       Ha Noi|Winter|        32.0|         5.5|
# |   Phan Thiet|Autumn|        32.0|        23.0|
# |       Ca Mau|Spring|        33.5|        21.0|
# |    Hai Phong|Summer|        34.0|        24.0|
# |      Cam Pha|Winter|        25.5|         6.5|
# +-------------+------+------------+------------+
# only showing top 20 rows

# %%
# 3. Tính trung bình cực trị của các yếu tố khí hậu của một tỉnh theo năm
df = df.withColumn("year", year(col("date")))
for col_name in analysis_cols:
    # Calculate max and min first
    extreme_df = df.groupBy("province", "year").agg(
        max(col_name).alias(f"max_{col_name}"),
        min(col_name).alias(f"min_{col_name}")
    )
    # Then calculate the average of max and min in a separate step
    extreme_avg_by_year = extreme_df.groupBy("province", "year").agg( # Group by both province and year
        avg(col(f"max_{col_name}")).alias(f"avg_max_{col_name}"),
        avg(col(f"min_{col_name}")).alias(f"avg_min_{col_name}")
    )
    print(f"Trung bình cực trị của {col_name} theo tỉnh và năm:")
    extreme_avg_by_year.show()
# Out:
# Trung bình cực trị của maxtemp theo tỉnh và năm:
# +----------+----+---------------+---------------+
# |  province|year|avg_max_maxtemp|avg_min_maxtemp|
# +----------+----+---------------+---------------+
# |    Ha Noi|2013|           44.0|           11.0|
# |  Bien Hoa|2021|           38.0|           25.0|
# |    Ha Noi|2011|           40.0|           11.0|
# |  Hoa Binh|2012|           46.0|           12.0|
# |  Hoa Binh|2020|           41.0|           12.0|
# |   Cam Pha|2020|           33.0|           14.0|
# |  Chau Doc|2011|           38.0|           25.0|
# |   Play Cu|2014|           38.0|           20.0|
# |  Hoa Binh|2011|           38.0|            9.0|
# |   Ben Tre|2013|           38.0|           26.0|
# |   Cam Pha|2011|           33.0|           11.0|
# |     Hanoi|2011|           40.0|           11.0|
# | Nha Trang|2016|           34.0|           20.0|
# | Nha Trang|2020|           33.0|           22.0|
# |  Cam Ranh|2020|           32.0|           22.0|
# | Hai Duong|2015|           40.0|           12.0|
# |Long Xuyen|2019|           39.0|           25.0|
# |    Tam Ky|2018|           39.0|           18.0|
# |   Can Tho|2012|           37.0|           26.0|
# |    Da Lat|2020|           33.0|           17.0|
# +----------+----+---------------+---------------+
# only showing top 20 rows
#
# Trung bình cực trị của mintemp theo tỉnh và năm:
# +----------+----+---------------+---------------+
# |  province|year|avg_max_mintemp|avg_min_mintemp|
# +----------+----+---------------+---------------+
# |    Ha Noi|2013|           29.0|            9.0|
# |  Bien Hoa|2021|           29.0|           18.0|
# |    Ha Noi|2011|           28.0|            6.0|
# |  Hoa Binh|2012|           28.0|            7.0|
# |  Hoa Binh|2020|           30.0|            8.0|
# |   Cam Pha|2020|           29.0|            9.0|
# |  Chau Doc|2011|           28.0|           18.0|
# |   Play Cu|2014|           22.0|            8.0|
# |  Hoa Binh|2011|           27.0|            6.0|
# |   Ben Tre|2013|           29.0|           21.0|
# |   Cam Pha|2011|           29.0|            8.0|
# |     Hanoi|2011|           28.0|            6.0|
# | Nha Trang|2016|           28.0|           17.0|
# | Nha Trang|2020|           27.0|           13.0|
# |  Cam Ranh|2020|           28.0|           14.0|
# | Hai Duong|2015|           30.0|           11.0|
# |Long Xuyen|2019|           30.0|           20.0|
# |    Tam Ky|2018|           28.0|           14.0|
# |   Can Tho|2012|           28.0|           21.0|
# |    Da Lat|2020|           21.0|           11.0|
# +----------+----+---------------+---------------+
# only showing top 20 rows
#
# Trung bình cực trị của wind theo tỉnh và năm:
# +----------+----+------------+------------+
# |  province|year|avg_max_wind|avg_min_wind|
# +----------+----+------------+------------+
# |    Ha Noi|2013|        16.0|         2.0|
# |  Bien Hoa|2021|        18.0|         4.0|
# |    Ha Noi|2011|        23.0|         3.0|
# |  Hoa Binh|2012|        12.0|         2.0|
# |  Hoa Binh|2020|        10.0|         2.0|
# |   Cam Pha|2020|        29.0|         4.0|
# |  Chau Doc|2011|        24.0|         3.0|
# |   Play Cu|2014|        20.0|         3.0|
# |  Hoa Binh|2011|        13.0|         2.0|
# |   Ben Tre|2013|        23.0|         4.0|
# |   Cam Pha|2011|        39.0|         5.0|
# |     Hanoi|2011|        23.0|         3.0|
# | Nha Trang|2016|        31.0|         4.0|
# | Nha Trang|2020|        28.0|         4.0|
# |  Cam Ranh|2020|        44.0|         5.0|
# | Hai Duong|2015|        27.0|         5.0|
# |Long Xuyen|2019|        26.0|         5.0|
# |    Tam Ky|2018|        25.0|         5.0|
# |   Can Tho|2012|        22.0|         4.0|
# |    Da Lat|2020|        15.0|         1.0|
# +----------+----+------------+------------+
# only showing top 20 rows
#
# Trung bình cực trị của rain theo tỉnh và năm:
# +----------+----+------------+------------+
# |  province|year|avg_max_rain|avg_min_rain|
# +----------+----+------------+------------+
# |    Ha Noi|2013|        40.0|         0.0|
# |  Bien Hoa|2021|        45.2|         0.0|
# |    Ha Noi|2011|        59.9|         0.0|
# |  Hoa Binh|2012|        75.7|         0.0|
# |  Hoa Binh|2020|        97.2|         0.0|
# |   Cam Pha|2020|       226.7|         0.0|
# |  Chau Doc|2011|        57.3|         0.0|
# |   Play Cu|2014|        76.9|         0.0|
# |  Hoa Binh|2011|       113.1|         0.0|
# |   Ben Tre|2013|        17.5|         0.0|
# |   Cam Pha|2011|       102.4|         0.0|
# |     Hanoi|2011|        59.9|         0.0|
# | Nha Trang|2016|       205.2|         0.0|
# | Nha Trang|2020|       290.1|         0.0|
# |  Cam Ranh|2020|       193.3|         0.0|
# | Hai Duong|2015|       140.5|         0.0|
# |Long Xuyen|2019|       107.2|         0.0|
# |    Tam Ky|2018|       104.5|         0.0|
# |   Can Tho|2012|        23.9|         0.0|
# |    Da Lat|2020|       119.7|         0.0|
# +----------+----+------------+------------+
# only showing top 20 rows
#
# Trung bình cực trị của humidity theo tỉnh và năm:
# +----------+----+----------------+----------------+
# |  province|year|avg_max_humidity|avg_min_humidity|
# +----------+----+----------------+----------------+
# |    Ha Noi|2013|            96.0|            42.0|
# |  Bien Hoa|2021|            93.0|            47.0|
# |    Ha Noi|2011|            96.0|            39.0|
# |  Hoa Binh|2012|            98.0|            42.0|
# |  Hoa Binh|2020|            98.0|            44.0|
# |   Cam Pha|2020|            95.0|            47.0|
# |  Chau Doc|2011|            93.0|            55.0|
# |   Play Cu|2014|           100.0|            55.0|
# |  Hoa Binh|2011|            99.0|            52.0|
# |   Ben Tre|2013|            91.0|            59.0|
# |   Cam Pha|2011|            96.0|            41.0|
# |     Hanoi|2011|            96.0|            39.0|
# | Nha Trang|2016|            94.0|            60.0|
# | Nha Trang|2020|            95.0|            70.0|
# |  Cam Ranh|2020|            95.0|            67.0|
# | Hai Duong|2015|            93.0|            51.0|
# |Long Xuyen|2019|            92.0|            48.0|
# |    Tam Ky|2018|            94.0|            56.0|
# |   Can Tho|2012|            91.0|            59.0|
# |    Da Lat|2020|            99.0|            37.0|
# +----------+----+----------------+----------------+
# only showing top 20 rows
#
# Trung bình cực trị của cloud theo tỉnh và năm:
# +----------+----+-------------+-------------+
# |  province|year|avg_max_cloud|avg_min_cloud|
# +----------+----+-------------+-------------+
# |    Ha Noi|2013|        100.0|          0.0|
# |  Bien Hoa|2021|         94.0|          3.0|
# |    Ha Noi|2011|         98.0|          1.0|
# |  Hoa Binh|2012|         96.0|          0.0|
# |  Hoa Binh|2020|        100.0|          4.0|
# |   Cam Pha|2020|        100.0|          4.0|
# |  Chau Doc|2011|         90.0|          1.0|
# |   Play Cu|2014|        100.0|          4.0|
# |  Hoa Binh|2011|         99.0|          1.0|
# |   Ben Tre|2013|         80.0|          1.0|
# |   Cam Pha|2011|        100.0|          1.0|
# |     Hanoi|2011|         98.0|          1.0|
# | Nha Trang|2016|        100.0|          0.0|
# | Nha Trang|2020|        100.0|          2.0|
# |  Cam Ranh|2020|        100.0|          0.0|
# | Hai Duong|2015|        100.0|          0.0|
# |Long Xuyen|2019|         91.0|          1.0|
# |    Tam Ky|2018|        100.0|          2.0|
# |   Can Tho|2012|         93.0|          5.0|
# |    Da Lat|2020|        100.0|          1.0|
# +----------+----+-------------+-------------+
# only showing top 20 rows
#
# Trung bình cực trị của pressure theo tỉnh và năm:
# +----------+----+----------------+----------------+
# |  province|year|avg_max_pressure|avg_min_pressure|
# +----------+----+----------------+----------------+
# |    Ha Noi|2013|          1025.0|           998.0|
# |  Bien Hoa|2021|          1013.0|          1005.0|
# |    Ha Noi|2011|          1026.0|           995.0|
# |  Hoa Binh|2012|          1026.0|           998.0|
# |  Hoa Binh|2020|          1026.0|           998.0|
# |   Cam Pha|2020|          1026.0|           997.0|
# |  Chau Doc|2011|          1013.0|          1003.0|
# |   Play Cu|2014|          1020.0|          1003.0|
# |  Hoa Binh|2011|          1025.0|           996.0|
# |   Ben Tre|2013|          1013.0|          1004.0|
# |   Cam Pha|2011|          1025.0|           993.0|
# |     Hanoi|2011|          1026.0|           995.0|
# | Nha Trang|2016|          1020.0|          1003.0|
# | Nha Trang|2020|          1019.0|          1002.0|
# |  Cam Ranh|2020|          1018.0|          1002.0|
# | Hai Duong|2015|          1027.0|           996.0|
# |Long Xuyen|2019|          1015.0|          1005.0|
# |    Tam Ky|2018|          1022.0|          1000.0|
# |   Can Tho|2012|          1013.0|          1003.0|
# |    Da Lat|2020|          1018.0|          1003.0|
# +----------+----+----------------+----------------+
# only showing top 20 rows
#
# Trung bình cực trị của temp theo tỉnh và năm:
# +----------+----+------------+------------+
# |  province|year|avg_max_temp|avg_min_temp|
# +----------+----+------------+------------+
# |    Ha Noi|2013|        36.0|        11.0|
# |  Bien Hoa|2021|        33.5|        21.5|
# |    Ha Noi|2011|        33.5|         9.5|
# |  Hoa Binh|2012|        36.5|        10.5|
# |  Hoa Binh|2020|        35.0|        10.0|
# |   Cam Pha|2020|        30.5|        11.5|
# |  Chau Doc|2011|        31.5|        22.0|
# |   Play Cu|2014|        28.0|        15.0|
# |  Hoa Binh|2011|        31.5|         8.0|
# |   Ben Tre|2013|        33.5|        24.0|
# |   Cam Pha|2011|        31.0|        10.0|
# |     Hanoi|2011|        33.5|         9.5|
# | Nha Trang|2016|        30.5|        19.0|
# | Nha Trang|2020|        29.5|        18.0|
# |  Cam Ranh|2020|        29.5|        18.0|
# | Hai Duong|2015|        35.0|        11.5|
# |Long Xuyen|2019|        34.5|        24.0|
# |    Tam Ky|2018|        32.5|        17.0|
# |   Can Tho|2012|        32.5|        24.5|
# |    Da Lat|2020|        26.0|        14.5|
# +----------+----+------------+------------+
# only showing top 20 rows

# %%
# 4. Thông tin về tỉnh nào có yếu tố khí hậu cao, thấp nhất
for col_name in analysis_cols:
    max_value = df.agg(max(col_name)).first()[0]
    min_value = df.agg(min(col_name)).first()[0]

    max_province = df.filter(col(col_name) == max_value).select("province").first()[0]
    min_province = df.filter(col(col_name) == min_value).select("province").first()[0]

    print(f"Yếu tố {col_name}:")
    print(f"  Cao nhất: {max_value} ở tỉnh {max_province}")
    print(f"  Thấp nhất: {min_value} ở tỉnh {min_province}")
# Out:
# Yếu tố maxtemp:
#   Cao nhất: 46.0 ở tỉnh Hoa Binh
#   Thấp nhất: 4.0 ở tỉnh Hoa Binh
# Yếu tố mintemp:
#   Cao nhất: 32.0 ở tỉnh Ha Noi
#   Thấp nhất: 2.0 ở tỉnh Ha Noi
# Yếu tố wind:
#   Cao nhất: 54.0 ở tỉnh Tam Ky
#   Thấp nhất: 1.0 ở tỉnh Da Lat
# Yếu tố rain:
#   Cao nhất: 596.4 ở tỉnh Cam Ranh
#   Thấp nhất: 0.0 ở tỉnh Bac Lieu
# Yếu tố humidity:
#   Cao nhất: 100.0 ở tỉnh Da Lat
#   Thấp nhất: 23.0 ở tỉnh Hoa Binh
# Yếu tố cloud:
#   Cao nhất: 100.0 ở tỉnh Buon Me Thuot
#   Thấp nhất: 0.0 ở tỉnh Bac Lieu
# Yếu tố pressure:
#   Cao nhất: 1038.0 ở tỉnh Thai Nguyen
#   Thấp nhất: 988.0 ở tỉnh Tam Ky
# Yếu tố temp:
#   Cao nhất: 37.0 ở tỉnh Ha Noi
#   Thấp nhất: 3.5 ở tỉnh Hoa Binh

# %%
# 5. Xu hướng thay đổi lượng mưa và nhiệt độ trung bình của từng tỉnh
for province_name in df.select("province").distinct().rdd.flatMap(lambda x: x).collect():
    province_df = df.filter(col("province") == province_name)

    # Lượng mưa
    rain_trend = province_df.orderBy("year").select(
        "year", "rain",
        (col("rain") - F.lag("rain", 1).over(Window.orderBy("year"))).alias("rain_diff")
    ).agg(avg("rain_diff").alias("avg_rain_diff")).first().avg_rain_diff

    rain_trend_label = "Increasing" if rain_trend > 0 else "Decreasing" if rain_trend < 0 else "Stable"

    # Nhiệt độ trung bình
    avg_temp_trend = province_df.orderBy("year").select(
        "year", "temp",
        (col("temp") - F.lag("temp", 1).over(Window.orderBy("year"))).alias("temp_diff")
    ).agg(avg("temp_diff").alias("avg_temp_diff")).first().avg_temp_diff

    temp_trend_label = "Increasing" if avg_temp_trend > 0 else "Decreasing" if avg_temp_trend < 0 else "Stable"

    print(f"Tỉnh {province_name}:")
    print(f"  Xu hướng thay đổi lượng mưa: {rain_trend_label}")
    print(f"  Xu hướng thay đổi nhiệt độ trung bình: {temp_trend_label}")
# Out:
# Tỉnh Long Xuyen:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh My Tho:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Ho Chi Minh City:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Ben Tre:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Nha Trang:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Hong Gai:
#   Xu hướng thay đổi lượng mưa: Increasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Hai Phong:
#   Xu hướng thay đổi lượng mưa: Increasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Cam Pha:
#   Xu hướng thay đổi lượng mưa: Increasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Hai Duong:
#   Xu hướng thay đổi lượng mưa: Increasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Ca Mau:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Cam Ranh:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Play Cu:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Nam Dinh:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Chau Doc:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Can Tho:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Da Lat:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Qui Nhon:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Phan Thiet:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Tan An:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Hue:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Hanoi:
#   Xu hướng thay đổi lượng mưa: Increasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Ha Noi:
#   Xu hướng thay đổi lượng mưa: Increasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Hoa Binh:
#   Xu hướng thay đổi lượng mưa: Increasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Tam Ky:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Bien Hoa:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Bac Lieu:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Soc Trang:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Buon Me Thuot:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Rach Gia:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Phan Rang:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Thai Nguyen:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Uong Bi:
#   Xu hướng thay đổi lượng mưa: Increasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Yen Bai:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Vung Tau:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Vinh Long:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Tra Vinh:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Tuy Hoa:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Vinh:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Viet Tri:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing
# Tỉnh Thanh Hoa:
#   Xu hướng thay đổi lượng mưa: Decreasing
#   Xu hướng thay đổi nhiệt độ trung bình: Increasing

# %%
# 6. Thông tin về tỉnh có lượng mưa hoặc nhiệt độ cực trị trong 5 năm, 10 năm
for years in [5, 10]:
    max_year = df.agg(max("year")).first()[0]
    min_year = max_year - years + 1

    period_df = df.filter(col("year").between(min_year, max_year))

    max_rain = period_df.agg(max("rain")).first()[0]
    min_rain = period_df.agg(min("rain")).first()[0]
    max_rain_province = period_df.filter(col("rain") == max_rain).select("province").first()[0]
    min_rain_province = period_df.filter(col("rain") == min_rain).select("province").first()[0]

    max_temp = period_df.agg(max("temp")).first()[0]
    min_temp = period_df.agg(min("temp")).first()[0]
    max_temp_province = period_df.filter(col("temp") == max_temp).select("province").first()[0]
    min_temp_province = period_df.filter(col("temp") == min_temp).select("province").first()[0]

    print(f"Trong {years} năm gần đây ({min_year}-{max_year}):")
    print(f"  Lượng mưa cao nhất: {max_rain} ở tỉnh {max_rain_province}")
    print(f"  Lượng mưa thấp nhất: {min_rain} ở tỉnh {min_rain_province}")
    print(f"  Nhiệt độ trung bình cao nhất: {max_temp} ở tỉnh {max_temp_province}")
    print(f"  Nhiệt độ trung bình thấp nhất: {min_temp} ở tỉnh {min_temp_province}")
# Out:
# Trong 5 năm gần đây (2017-2021):
#   Lượng mưa cao nhất: 596.4 ở tỉnh Cam Ranh
#   Lượng mưa thấp nhất: 0.0 ở tỉnh Bac Lieu
#   Nhiệt độ trung bình cao nhất: 36.5 ở tỉnh Ha Noi
#   Nhiệt độ trung bình thấp nhất: 4.5 ở tỉnh Uong Bi
# Trong 10 năm gần đây (2012-2021):
#   Lượng mưa cao nhất: 596.4 ở tỉnh Cam Ranh
#   Lượng mưa thấp nhất: 0.0 ở tỉnh Bac Lieu
#   Nhiệt độ trung bình cao nhất: 37.0 ở tỉnh Ha Noi
#   Nhiệt độ trung bình thấp nhất: 3.5 ở tỉnh Hoa Binh

# %%
# 7. Hệ số tương quan giữa các yếu tố khí hậu của Hà Nội trong năm 2019
province_name = "Ha Noi"  # Specify the province
year_val = 2019  # Specify the year

# Filter data for the specific province and year
year_df = df.filter((col("province") == province_name) & (year(col("date")) == year_val))

print(f"Hệ số tương quan giữa các yếu tố khí hậu của tỉnh {province_name} trong năm {year_val}:")

correlation_matrix = {}
for i in range(len(analysis_cols)):
  for j in range(i + 1, len(analysis_cols)):
    col1 = analysis_cols[i]
    col2 = analysis_cols[j]
    correlation = year_df.select(corr(col1, col2)).first()[0]
    # Check if correlation is None before adding to the matrix
    if correlation is not None:
        correlation_matrix[(col1, col2)] = correlation
    else:
        # Handle the case where correlation is None (e.g., print a message or assign a default value)
        print(f"Correlation between {col1} and {col2} is None. Check your data or calculation.")
        correlation_matrix[(col1, col2)] = 0.0  # For example, assign 0.0

# In bảng hệ số tương quan
header = f"{'':<15}" + "".join([f"{col:<15}" for col in analysis_cols])
print(header)
for col1 in analysis_cols:
    row = f"{col1:<15}"
    for col2 in analysis_cols:
        if (col1, col2) in correlation_matrix:
            row += f"{correlation_matrix[(col1, col2)]:<15.2f}"
        elif (col2, col1) in correlation_matrix:
            row += f"{correlation_matrix[(col2, col1)]:<15.2f}"
        else:
            row += f"{1.0:<15.2f}"  # Đường chéo chính
    print(row)
print("\n")
# Out:
# Hệ số tương quan giữa các yếu tố khí hậu của tỉnh Ha Noi trong năm 2019:
#                maxtemp        mintemp        wind           rain           humidity       cloud          pressure       temp
# maxtemp        1.00           0.90           -0.05          0.05           -0.10          -0.66          -0.82          0.98
# mintemp        0.90           1.00           0.02           0.24           0.20           -0.40          -0.89          0.97
# wind           -0.05          0.02           1.00           0.08           0.17           0.21           0.04           -0.02
# rain           0.05           0.24           0.08           1.00           0.41           0.16           -0.33          0.14
# humidity       -0.10          0.20           0.17           0.41           1.00           0.60           -0.19          0.03
# cloud          -0.66          -0.40          0.21           0.16           0.60           1.00           0.35           -0.56
# pressure       -0.82          -0.89          0.04           -0.33          -0.19          0.35           1.00           -0.87
# temp           0.98           0.97           -0.02          0.14           0.03           -0.56          -0.87          1.00

# %%
spark.stop()
